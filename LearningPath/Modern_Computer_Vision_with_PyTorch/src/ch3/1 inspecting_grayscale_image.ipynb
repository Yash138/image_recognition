# %%
# !wget https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg
# Out:
# --2023-11-18 16:46:00--  https://www.dropbox.com/s/l98leemr7r5stnm/Hemanvi.jpeg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/l98leemr7r5stnm/Hemanvi.jpeg [following]
# --2023-11-18 16:46:01--  https://www.dropbox.com/s/raw/l98leemr7r5stnm/Hemanvi.jpeg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc33288b7255289d1edb8e2d9ef.dl.dropboxusercontent.com/cd/0/inline/CHwkNBAuYqdbecJuVf1wDQkiaxAGVo8NQ212ntAPVo6aFs7XkiZvIleLY1weSYiH7EeiE5yXE1U9ERMfN_mkZVV2npa3E4gA0a8oaxgadwbhilwle7moGbjL9TwG-sKMJq03cBGI0vtgZr2Mgd2kQUMR/file# [following]
# --2023-11-18 16:46:02--  https://ucc33288b7255289d1edb8e2d9ef.dl.dropboxusercontent.com/cd/0/inline/CHwkNBAuYqdbecJuVf1wDQkiaxAGVo8NQ212ntAPVo6aFs7XkiZvIleLY1weSYiH7EeiE5yXE1U9ERMfN_mkZVV2npa3E4gA0a8oaxgadwbhilwle7moGbjL9TwG-sKMJq03cBGI0vtgZr2Mgd2kQUMR/file
# Resolving ucc33288b7255289d1edb8e2d9ef.dl.dropboxusercontent.com (ucc33288b7255289d1edb8e2d9ef.dl.dropboxusercontent.com)... 162.125.81.15
# Connecting to ucc33288b7255289d1edb8e2d9ef.dl.dropboxusercontent.com (ucc33288b7255289d1edb8e2d9ef.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53839 (53K) [image/jpeg]
# Saving to: 'Hemanvi.jpeg'
#
#      0K .......... .......... .......... .......... .......... 95%  286K 0s
#     50K ..                                                    100% 49.2G=0.2s
#
# 2023-11-18 16:46:03 (300 KB/s) - 'Hemanvi.jpeg' saved [53839/53839]

# %%
# %matplotlib inline
import cv2, matplotlib.pyplot as plt
img = cv2.imread('Hemanvi.jpeg')

# %%
img = img[50:250,40:240]

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')
